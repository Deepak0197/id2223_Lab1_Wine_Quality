# %%
#Required only if dataframe_image is not already installed.
# !pip install dataframe_image
# Out:
# Requirement already satisfied: dataframe_image in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: pandas>=0.24 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (1.4.4)
# Requirement already satisfied: nbconvert>=5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (6.4.4)
# Requirement already satisfied: aiohttp in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (3.8.3)
# Requirement already satisfied: requests in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (2.28.1)
# Requirement already satisfied: pillow in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (9.2.0)
# Requirement already satisfied: packaging in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (21.3)
# Requirement already satisfied: mistune in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (0.8.4)
# Requirement already satisfied: lxml in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (4.11.1)
# Requirement already satisfied: cssutils in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (2.9.0)
# Requirement already satisfied: html2image in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from dataframe_image) (2.0.4.3)
# Requirement already satisfied: jinja2>=2.4 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (2.11.3)
# Requirement already satisfied: pygments>=2.4.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (2.16.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (0.1.2)
# Requirement already satisfied: traitlets>=5.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (5.1.1)
# Requirement already satisfied: jupyter-core in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (4.11.2)
# Requirement already satisfied: nbformat>=4.4 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (5.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (0.4)
# Requirement already satisfied: bleach in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (1.5.0)
# Requirement already satisfied: testpath in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (0.6.0)
# Requirement already satisfied: defusedxml in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image) (0.5.13)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->dataframe_image) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->dataframe_image) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->dataframe_image) (1.22.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->dataframe_image) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->dataframe_image) (2.3.2.post1)
# Requirement already satisfied: websocket-client<2.0.0,>=1.0.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from html2image->dataframe_image) (1.6.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from packaging->dataframe_image) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from requests->dataframe_image) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from requests->dataframe_image) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from requests->dataframe_image) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert>=5->dataframe_image) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image) (7.4.7)
# Requirement already satisfied: nest-asyncio in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image) (1.5.5)
# Requirement already satisfied: fastjsonschema in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image) (4.16.0)
# Requirement already satisfied: six>=1.5 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.24->dataframe_image) (1.16.0)
# Requirement already satisfied: webencodings in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->dataframe_image) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5->dataframe_image) (0.18.0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image) (23.2.0)
# Requirement already satisfied: tornado>=6.2 in /Users/deepakshankar/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image) (6.2)
# WARNING: There was an error checking the latest version of pip.

# %%
LOCAL=True

if LOCAL == False:
   stub = modal.Stub()
   hopsworks_image = modal.Image.debian_slim().pip_install(["hopsworks","joblib","seaborn","sklearn==1.1.1","dataframe-image"])
   @stub.function(image=hopsworks_image, schedule=modal.Period(days=1), secret=modal.Secret.from_name("HOPSWORKS_API_KEY"))
   def f():
       g()

def g():
    import pandas as pd
    import hopsworks
    import joblib
    import datetime
    from PIL import Image
    from datetime import datetime
    import dataframe_image as dfi
    from sklearn.metrics import confusion_matrix
    from matplotlib import pyplot
    import seaborn as sns
    import requests

    project = hopsworks.login()
    fs = project.get_feature_store()
    
    mr = project.get_model_registry()
    model = mr.get_model("wine_model", version=1)
    model_dir = model.download()
    model = joblib.load(model_dir + "/wine_model.pkl")
    
    feature_view = fs.get_feature_view(name="wine", version=1)
    batch_data = feature_view.get_batch_data()
    
    y_pred = model.predict(batch_data)
    #print(y_pred)
    offset = 1
    quality = y_pred[y_pred.size-offset]
#   quality_url = "https://raw.githubusercontent.com/featurestoreorg/serverless-ml-course/main/src/01-module/assets/" + quality + ".png"
    print("Wine Quality predicted: " + quality)
#     img = Image.open(requests.get(quality_url, stream=True).raw)            
#     img.save("./latest_wine_quality.png")
    dataset_api = project.get_dataset_api()    
#     dataset_api.upload("./latest_wine_quality.png", "Resources/images", overwrite=True)
   
    iris_fg = fs.get_feature_group(name="wine", version=1)
    df = iris_fg.read() 
    #print(df)
    label = df.iloc[-offset]["quality"]
#     label_url = "https://raw.githubusercontent.com/featurestoreorg/serverless-ml-course/main/src/01-module/assets/" + label + ".png"
    print("Wine Quality actual: " + label)
    img = Image.open(requests.get(label_url, stream=True).raw)            
    img.save("./actual_wine_quality.png")
    dataset_api.upload("./actual_wine_quality.png", "Resources/images", overwrite=True)
    
    monitor_fg = fs.get_or_create_feature_group(name="wine_quality_predictions",
                                                version=1,
                                                primary_key=["datetime"],
                                                description="Wine Quality Prediction/Outcome Monitoring"
                                                )
    
    now = datetime.now().strftime("%m/%d/%Y, %H:%M:%S")
    data = {
        'prediction': [quality],
        'label': [label],
        'datetime': [now],
       }
    monitor_df = pd.DataFrame(data)
    monitor_fg.insert(monitor_df, write_options={"wait_for_job" : False})
    
    history_df = monitor_fg.read()
    # Add our prediction to the history, as the history_df won't have it - 
    # the insertion was done asynchronously, so it will take ~1 min to land on App
    history_df = pd.concat([history_df, monitor_df])


    df_recent = history_df.tail(4)
    dfi.export(df_recent, './df_recent.png', table_conversion = 'matplotlib')
    dataset_api.upload("./df_recent.png", "Resources/images", overwrite=True)
    
    predictions = history_df[['prediction']]
    labels = history_df[['label']]

    # Only create the confusion matrix when our wine_quality_predictions feature group has examples of all 6 values - 3 to 8.
    print("Number of different Wine Quality predictions to date: " + str(predictions.value_counts().count()))
    if predictions.value_counts().count() == 6:
        results = confusion_matrix(labels, predictions)
    
        df_cm = pd.DataFrame(results, ['True 3', 'True 4', 'True 5', 'True 6', 'True 7', 'True 8'],
                             ['Pred 3', 'Pred 4', 'Pred 5', 'Pred 6', 'Pred 7', 'Pred 8'])
    
        cm = sns.heatmap(df_cm, annot=True)
        fig = cm.get_figure()
        fig.savefig("./confusion_matrix.png")
        dataset_api.upload("./confusion_matrix.png", "Resources/images", overwrite=True)
    else:
        print("You need 6 different Wine Quality predictions to create the confusion matrix.")
        print("Run the batch inference pipeline more times until you get 6 different Wine Quality predictions.") 


if __name__ == "__main__":
    if LOCAL == True :
        g()
    else:
        with stub.run():
            f()
